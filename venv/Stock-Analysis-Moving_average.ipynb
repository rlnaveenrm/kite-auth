# %%
from nsepy import get_history
from datetime import date
import matplotlib as plt
import nsepy

#from nsepy import get_history
#from datetime import date
#import matplotlib as plt
#import nsepy
#data = get_history(symbol="SBIN", start=date(2015,1,1), end=date(2015,1,31))
#data[['Close']].plot()
#type(data)
#nsepy.live()

# Give the data 
# stock_id--> example 'SBIN'
# start_date, end_date should be in the format date(year,month,date)
# return the panda dataframe
def getdata(stock_id, start_date,end_date):
    return(get_history(symbol=stock_id,start=start_date,end=end_date))


sbin_data=getdata('SBIN',date(2015,1,1),date(2016,1,1))
sbin_data
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2015-12-28   SBIN     EQ      228.30  229.05  229.95  228.00  228.60  228.90
# 2015-12-29   SBIN     EQ      228.90  228.85  229.95  227.50  228.40  228.20
# 2015-12-30   SBIN     EQ      228.20  229.00  229.70  224.85  225.95  225.80
# 2015-12-31   SBIN     EQ      225.80  225.95  226.55  224.00  224.75  224.45
# 2016-01-01   SBIN     EQ      224.45  225.00  228.90  224.50  227.75  227.80
#
# ...

# %%
# processing
# remmove the weekend values from the dataframe
sbin_data=sbin_data[(sbin_data['Close'])!=0]
sbin_data["3weekMA"]=sbin_data["Close"].rolling(15).mean()
sbin_data
sbin_data['Close'].plot()
sbin_data['3weekMA'].plot()
#plt.plot(sbin_data['Close'].values.tolist()[7:-7])
#plt.plot(sbin_data['3weekMA'].values.tolist()[14:])
